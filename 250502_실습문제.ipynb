# %% [markdown]
# <a href="https://colab.research.google.com/github/seungyeon1203/AI-python/blob/main/250502_%EC%8B%A4%EC%8A%B5%EB%AC%B8%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **08장 연습문제**

# %% [markdown]
# 1번

# %%
# !pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
#선그래프
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May']
temperatures = [5, 7, 12, 18, 22]
plt.rcParams['font.family'] = 'sans-serif'
plt.plot(months, temperatures) # 선그래프를 그릴때 x축은 월 데이터, y축은 온도 데이터 순서로 입력
plt.title('Monthly Temperature Change') # 그래프 제목
plt.xlabel('Month')                 # x축 이름
plt.ylabel('Temperature (C)')       # y축 이름
plt.show()                          # 그래프 보여주기 (매개변수 없이)

# %%
months
# Out:
# ['Jan', 'Feb', 'Mar', 'Apr', 'May']

# %%
print(temperatures)
# Out:
# [5, 7, 12, 18, 22]

# %%
#산점도
height = [160, 165, 170, 175, 180]
weight = [55, 60, 68, 72, 78]

#주석 다는 코두- plt.annotate()
plt.rcParams['font.family'] = 'sans-serif'
plt.scatter(height, weight) # x축 데이터, y축 데이터
plt.title('Height vs Weight')
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.show()

#두 변수와의 관계를 나타내는 산점도 시각화 (정적 관계 그래프)

# %%
#막대그래프
fruits = ['Apple', 'Banana', 'Orange']
sales = [100, 150, 80]

plt.bar(fruits, sales) # x축 카테고리, y축 값
plt.title('Fruit Sales')
plt.xlabel('Fruit')
plt.ylabel('Quantity Sold')
plt.show()

# %%
#히스토그램
scores = [65, 72, 75, 78, 80, 82, 85, 88, 90, 91, 93, 95, 98, 100]

plt.hist(scores, bins=5) # 데이터, 구간(bin) 개수 5개 설정-> 구간별 빈도수를 보자
plt.title('Exam Score Distribution')
plt.xlabel('Score')
plt.ylabel('Number of Students')
plt.show()

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# ^C

# %%
year = [2006, 2009, 2012, 2015, 2018]
kor = [547, 546, 554, 524, 526]

plt.plot(year, kor)
plt.title('Year Kor Change')
plt.xlabel('Year')
plt.ylabel('Kor')
plt.show()

# %%
import matplotlib.pyplot as plt

year = ['2006', '2009', '2012', '2015', '2018']
kor = [547, 546, 554, 524, 526]
plt.bar(year, kor) # x축 카테고리, y축 값
plt.title('Year Kor')
plt.xlabel('Year')
plt.ylabel('Kor')
plt.show()

# %%
import matplotlib.pyplot as plt

kor = [547, 546, 554, 524, 526]
usa = [474, 487, 481, 470, 478]
plt.scatter(kor, usa) # x축 데이터, y축 데이터
plt.title('kor vs usa')
plt.xlabel('kor')
plt.ylabel('usa')
plt.show()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'sans-serif'
score = [547,546,554,524,526,474,487,481,470,478,523,529,536,532,527]
plt.hist(score, bins=5) # 데이터, 구간(bin) 개수 5개 설정-> 구간별 빈도수를 보자
plt.title('Exam Score Distribution')
plt.xlabel('Score')
plt.ylabel('Number of Students')
plt.show()

# %%
import matplotlib.pyplot as plt

x = [2009, 2012, 2015]
y = [529, 536, 532]
plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [2006, 2009, 2012, 2015]
y = [523, 529, 536, 532]
plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = ['a', 'b', 'c']
y = [7, 5, 4]
plt.bar(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

year = [2006, 2009, 2012, 2015, 2018]
kor = [547, 546, 554, 524, 526]
plt.plot(year, kor)
plt.show()

# %%
import matplotlib.pyplot as plt

year = [2006, 2009, 2012, 2015, 2018]
kor = [547, 546, 554, 524, 526]
usa = [474, 487, 481, 470, 478]
# year kor 그래프
# year usa 그래프
plt.plot(year, kor, 'b-', label = 'Korea' )
plt.plot(year, usa, 'r-', label='USA')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

year = [2006, 2009, 2012, 2015, 2018]
kor = [547, 546, 554, 524, 526]
usa = [474, 487, 481, 470, 478]
jpn = [523, 529, 536, 532, 527]

# 그래프가 가로와 세로 크기를 각각 5인치와 3인치 크기 설정
plt.figure(figsize=(5, 3))
# year 데이터를 x축으로, kor 데이터를 y축으로 하여 빨간색 점선으로 선 그래프를 그리고 범례에 'Korea'라고 표시
plt.plot(year, kor, 'b:', label = 'Korea' ) #범례에 'Korea'라고 표시
plt.plot(year, jpn, 'g-', label='Japan')
plt.plot(year, usa, 'r-', label='USA')
plt.ylim(400, 600)  # y축 범위 설정
# 그래프에 범례를 추가
plt.legend()
# 그래프 제목을 'Mathematics performance'로 설정합니다.
plt.xlabel('year')
plt.ylabel('score')
plt.show()

# %%
import matplotlib.pyplot as plt

notebook = {'g○○':150,'t○○':100,'m○○':160,'s○○':170}

plt.figure(figsize=(5,3))
# 막대 그래프의 x축은 딕셔너리의 키(제품이름)를 사용하고, 막대 그래프의 Y축은 딕셔너리의 값(가격)을 사용하고, 각 막대의 너비를 0.7 단위로 설정
plt.xlabel('product name')
plt.ylabel('price')
plt.show()

# %%
import matplotlib.pyplot as plt

year = [2000, 2005, 2010, 2015, 2020]
single_person = [15.5, 20.0, 23.9, 27.2, 31.7]
baby_born = [640089, 438707, 470171, 438420, 272337]

plt.figure(figsize=(5,3))
 # 1인 가구 비율(single_person)과 출생아 수(baby_born) 사이의 관계를 나타내는 산점도를 그립니다.
for i in range(len(year)):
  plt.annotate(year[i],xy=(single_person[i], baby_born[i]),xytext=(5,-10),textcoords='offset points') #각 연도에 해당하는 데이터 지점 옆에 해당 연도를 표시하는 주석을 추가
plt.xlim(14,35)
plt.ylim(230000,700000)
plt.xlabel('single-person household ratio')
plt.ylabel('the number of babies born')
plt.show()

# %%
import matplotlib.pyplot as plt
import random

x = [random.randint(1,100) for i in range(1000)]

plt.figure(figsize=(5,3))
# 데이터 배열 x를 20개의 구간으로 나누고 50% 투명도로 표시하는 빈도 분포 그래프를 생성
plt.ylabel('frequency')
plt.show()

# %%
import matplotlib.pyplot as plt

exercise ={'climbing':0,'soccer':0,'swimming':0,'tennis':0}

print('좋아하는 운동을 입력하세요.')
print('복수 개의 운동을 입력하려면 콤마로 구분하세요.')

while True:
  s = input('climbing,soccer,swimming,tennis,종료: ')
  if s=='종료':
    break
    for a in s.split(','):
      if a in exercise:
        exercise[a] += 1
      else:
        print(f'{a}는 등록되지 않은 운동입니다.')

plt.figure(figsize=(5.5,3))
plt.bar(exercise.keys(), exercise.values(), color='g', width=0.6)
#plt.xticks(rotation='vertical')
plt.xlabel('exercise')
plt.ylabel('frequency')
plt.show()
# Out:
# 좋아하는 운동을 입력하세요.
# 복수 개의 운동을 입력하려면 콤마로 구분하세요.
# climbing,soccer,swimming,tennis,종료: climbing
# climbing,soccer,swimming,tennis,종료: 종료

# %%
#다음 데이터를 이용하여 1년 동안의 월별 평균 강수량을 꺾은선 그래프로 그려보세요.

m = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
r = [30, 40, 60, 80, 100, 150, 300, 280, 120, 70, 50, 35]
plt.figure(figsize=(12,6))
for i in range(len(m)):
    plt.annotate(r[i], (m[i], r[i]), xytext=(5, 5), textcoords='offset points')
plt.plot(m, r, color='y', marker='s', linestyle = '-.')
plt.title('average monthly rainfall')
plt.xlabel('m')
plt.ylabel('r')
plt.show()

#그래프 제목과 x, y축 레이블을 추가하세요.
