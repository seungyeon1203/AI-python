# %% [markdown]
# <a href="https://colab.research.google.com/github/seungyeon1203/AI-python/blob/main/250516ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#데이터 파일 불러오기
# !pip install pandas
import pandas as pd
df = pd.read_csv('/content/example_data.csv')
df
# Out:
# ...
#     학번    이름   학년   점수 분반  공부시간
# 0    1  신사임당  NaN   69  B     4
# 1    2   홍길동  1.0   92  B     3
# 2    3   강감찬  4.0   91  C    20
# 3    4   강감찬  2.0   70  C     5
# 4    5   강감찬  3.0   83  C     5
# 5    6   이순신  4.0   95  A     0
# 6    7   강감찬  4.0   71  C     1
# 7    8   김유신  NaN   88  B     5
# 8    9  신사임당  3.0   94  A     9
# 9   10   홍길동  NaN   60  B     3
# 10  11   NaN  1.0  200  C     0
# 11  12  신사임당  2.0   96  A    20
# 12  13   김유신  4.0   65  A     0
# 13  14   NaN  2.0   98  C     1
# 14  15   홍길동  4.0   77  A     2
# 15  16   이순신  4.0   75  A     4
# 16  17   NaN  3.0   64  A     2
# 17  18   홍길동  4.0   91  A     0
# 18  19   이순신  1.0  200  A     3
# 19  20  신사임당  2.0   61  A     2
# 20  20  신사임당  2.0   61  A     2

# %%
#기본 정보 출력
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   학번      21 non-null     int64
#  1   이름      18 non-null     object
#  2   학년      18 non-null     float64
#  3   점수      21 non-null     int64
#  4   분반      21 non-null     object
#  5   공부시간    21 non-null     int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 1.1+ KB

# %%
#숫자 데이터의 기초 통계량 출력
df.describe()
# Out:
#               학번         학년          점수       공부시간
# count  21.000000  18.000000   21.000000  21.000000
# mean   10.952381   2.777778   90.523810   4.333333
# std     6.127611   1.165966   38.647922   5.650959
# min     1.000000   1.000000   60.000000   0.000000
# 25%     6.000000   2.000000   69.000000   1.000000
# 50%    11.000000   3.000000   83.000000   3.000000
# 75%    16.000000   4.000000   94.000000   5.000000
# max    20.000000   4.000000  200.000000  20.000000

# %%
#결측치 확인하기
df.isnull().sum()
# Out:
# 학번      0
# 이름      3
# 학년      3
# 점수      0
# 분반      0
# 공부시간    0
# dtype: int64

# %%
#이상치 확인하기 1
#(점수 > 100 또는 공부시간 > 10 인 데이터) (조건식으로 확인)
df.query('점수 > 100 or 공부시간 > 10')
# Out:
#     학번    이름   학년   점수 분반  공부시간
# 2    3   강감찬  4.0   91  C    20
# 10  11   NaN  1.0  200  C     0
# 11  12  신사임당  2.0   96  A    20
# 18  19   이순신  1.0  200  A     3

# %%
#이상치 확인하기 2
outlier_df = df[(df['점수'] > 100) | (df['공부시간'] > 10)]
print('이상치 개수', len(outlier_df))
print(outlier_df)
# Out:
# 이상치 개수 4
#     학번    이름   학년   점수 분반  공부시간
# 2    3   강감찬  4.0   91  C    20
# 10  11   NaN  1.0  200  C     0
# 11  12  신사임당  2.0   96  A    20
# 18  19   이순신  1.0  200  A     3

# %%
#중복 데이터 확인하기
#데이터프레임에서 중복된 행이 있는지 확인
duplicate_rows = df[df.duplicated()]
print(duplicate_rows)
# Out:
#     학번    이름   학년  점수 분반  공부시간
# 20  20  신사임당  2.0  61  A     2

# %%
#중복 데이터 확인하기
#데이터프레임에서 중복된 행이 있는지 확인 (ㅣen함수 사용)
duplicate_rows = df[df.duplicated()]
num_duplicate_rows = len(duplicate_rows)
print('중복된 행의 개수:', num_duplicate_rows)
# Out:
# 중복된 행의 개수: 1

# %%
#중복 데이터 확인하기
#데이터프레임에서 중복된 행이 있는지 확인
print('문제6: 완전 중복행 확인')
print(f'중복 제거 전 데이터 프레임 크기:{df.shape}')
duplicate_df = df[df.duplicated()]
num_duplicate_df = len(duplicate_df)
print('중복된 행의 개수:', num_duplicate_df)
# Out:
# 문제6: 완전 중복행 확인
# 중복 제거 전 데이터 프레임 크기:(21, 6)
# 중복된 행의 개수: 1

# %%
#중복 데이터 삭제하기
#데이터프레임에서 중복된 데이터를 삭제하고, 중복이 제거된 데이터프레임을 출력
df_no_duplicates = df.drop_duplicates()
num_rows_after_dropping_duplicates = len(df_no_duplicates)
print('중복 제거 후 데이터프레임의 행 개수:', num_rows_after_dropping_duplicates)
print(df_no_duplicates)
# Out:
# 중복 제거 후 데이터프레임의 행 개수: 20
#     학번    이름   학년   점수 분반  공부시간
# 0    1  신사임당  NaN   69  B     4
# 1    2   홍길동  1.0   92  B     3
# 2    3   강감찬  4.0   91  C    20
# 3    4   강감찬  2.0   70  C     5
# 4    5   강감찬  3.0   83  C     5
# 5    6   이순신  4.0   95  A     0
# 6    7   강감찬  4.0   71  C     1
# 7    8   김유신  NaN   88  B     5
# 8    9  신사임당  3.0   94  A     9
# 9   10   홍길동  NaN   60  B     3
# 10  11   NaN  1.0  200  C     0
# 11  12  신사임당  2.0   96  A    20
# 12  13   김유신  4.0   65  A     0
# 13  14   NaN  2.0   98  C     1
# 14  15   홍길동  4.0   77  A     2
# 15  16   이순신  4.0   75  A     4
# 16  17   NaN  3.0   64  A     2
# 17  18   홍길동  4.0   91  A     0
# 18  19   이순신  1.0  200  A     3
# 19  20  신사임당  2.0   61  A     2

# %%
#시각화
#공부시간과 점수에 대한 산점도 그래프를 작성
import matplotlib.pyplot as plt
plt.scatter(df['공부시간'], df['점수'])
plt.title('study_hours and score')
plt.xlabel('study_hours')
plt.ylabel('score')
plt.show()

# %% [markdown]
# 산점도 그래프를 통해 이상치 탐색 가능
# 대체적으로 공부시간과 점수는 상관관계가 있어보임

# %%
#점수 이상치
Q1_score = df['점수'].quantile(0.25)
Q3_score = df['점수'].quantile(0.75)
IQR_score = Q3_score - Q1_score

# %%
lower_bound_score = Q1_score - 1.5 * IQR_score
upper_bound_score = Q3_score + 1.5 * IQR_score

# %%
score_outliers = df[(df['점수'] < lower_bound_score) | (df['점수'] > upper_bound_score)]
print(score_outliers)
# Out:
#     학번   이름   학년   점수 분반  공부시간
# 10  11  NaN  1.0  200  C     0
# 18  19  이순신  1.0  200  A     3

# %%
#공부시간 이상치
Q1_study = df['공부시간'].quantile(0.25)
Q3_study = df['공부시간'].quantile(0.75)
IQR_study = Q3_study - Q1_study

# %%
lower_bound_study = Q1_study - 1.5 * IQR_study
upper_bound_study = Q3_study + 1.5 * IQR_study

# %%
study_outliers = df[(df['공부시간'] < lower_bound_study) | (df['공부시간'] > upper_bound_study)]
print(study_outliers)
# Out:
#     학번    이름   학년  점수 분반  공부시간
# 2    3   강감찬  4.0  91  C    20
# 11  12  신사임당  2.0  96  A    20

# %%
df_no_outliers = df[(df['점수'] >= lower_bound_score) & (df['점수'] <= upper_bound_score) & (df['공부시간'] >= lower_bound_study) & (df['공부시간'] <= upper_bound_study)]

# %%
df_no_outliers = df_no_outliers.reset_index(drop=True)
print("이상치가 제거된 데이터프레임:")
print(df_no_outliers)
# Out:
# 이상치가 제거된 데이터프레임:
#     학번    이름   학년  점수 분반  공부시간
# 0    1  신사임당  NaN  69  B     4
# 1    2   홍길동  1.0  92  B     3
# 2    4   강감찬  2.0  70  C     5
# 3    5   강감찬  3.0  83  C     5
# 4    6   이순신  4.0  95  A     0
# 5    7   강감찬  4.0  71  C     1
# 6    8   김유신  NaN  88  B     5
# 7    9  신사임당  3.0  94  A     9
# 8   10   홍길동  NaN  60  B     3
# 9   13   김유신  4.0  65  A     0
# 10  14   NaN  2.0  98  C     1
# 11  15   홍길동  4.0  77  A     2
# 12  16   이순신  4.0  75  A     4
# 13  17   NaN  3.0  64  A     2
# 14  18   홍길동  4.0  91  A     0
# 15  20  신사임당  2.0  61  A     2
# 16  20  신사임당  2.0  61  A     2

# %%
#분반별 점수 평균 계산
print("문제11. 분반별 점수 평균 계산")
class_means = df_no_outliers.groupby('분반')['점수'].mean()
print(class_means.round(2))
# Out:
# 문제11. 분반별 점수 평균 계산
# 분반
# A    75.89
# B    77.25
# C    80.50
# Name: 점수, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.bar(class_means.index, class_means.values)
plt.xlabel('분반')
plt.ylabel('평균 점수')
plt.title('분반별 평균 점수 그래프')
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# ...

# %%
plt.scatter(df_no_outliers ['공부시간'], df_no_outliers ['점수'])
plt.title('study_hours and score')
plt.xlabel('study_hours')
plt.ylabel('score')
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# ...
